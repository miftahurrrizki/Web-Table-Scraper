# %%
# !pip install fake_useragent

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# %%
ua = UserAgent() #buat ngasih tau situs web, kalo permintaan kita ngakses web itu sah ato bukan bot, pokonya sah
headers = {'User-Agent': ua.random}

# %%
url = "https://www.the-numbers.com/movie/budgets"  #link web yg mau di scrap
response = requests.get(url, headers=headers)
tabel = pd.read_html(response.text)
tabel
# Out:
# [    Unnamed: 0  Release Date                                        Movie  \
#  0          1.0  Dec 16, 2022                     Avatar: The Way of Water
#  1          NaN           NaN                                          NaN
#  2          2.0  Apr 26, 2019                            Avengers: Endgame
#  3          NaN           NaN                                          NaN
#  4          3.0  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#  5          NaN           NaN                                          NaN
#  6          4.0   May 1, 2015                      Avengers: Age of Ultron
#  7          NaN           NaN                                          NaN
#  8          5.0  May 19, 2023                                       Fast X
#  9          NaN           NaN                                          NaN
#  10         6.0  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# ...

# %%
tabel[2] #nampilin tabel ke -3 (index mulai dari 0)
# Out:
#     Unnamed: 0  Release Date                                          Movie  \
# 0          1.0  Dec 18, 2009                                         Avatar
# 1          NaN           NaN                                            NaN
# 2          2.0  Apr 26, 2019                              Avengers: Endgame
# 3          NaN           NaN                                            NaN
# 4          3.0  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 5          NaN           NaN                                            NaN
# 6          4.0  Nov 22, 2013                                         Frozen
# 7          NaN           NaN                                            NaN
# 8          5.0  Apr 27, 2018                         Avengers: Infinity War
# 9          NaN           NaN                                            NaN
# 10         6.0  Dec 19, 1997                                        Titanic
# ...

# %%
tabel[0].to_csv("/content/movie_budget.csv", index=False) #buat export tabel yg dipilih, misal disini tabel index 0
